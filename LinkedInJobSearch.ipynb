# %%
import pandas as pd
import bs4
import requests
import json
import pickle
import time

# %% [markdown]
# This notebook serves two purposes:
# 1. Archive job descriptions for future analysis
# 2. Automate job application process for jobs with inApply feature available

# %%
#Constants
RAW_PATH='./raw/'
PICKLE_PATH='./pickle/'
TODAY=time.strftime("%Y-%m-%d")
CSV_PATH='./csv/'
BASE_URL='https://www.linkedin.com'
SEARCH_TERM='Engineer'
TODAY_PICKLE_PATH=("%s%s_%s.pickle" % (PICKLE_PATH,SEARCH_TERM,TODAY))

# %%
def get_dict_from_url(url,codeID):
    """
    returns a dictionary from any data found in the first html 'code' element with given id in given url.
    requires a valid linkedIn session, sess.
    """
    resp=sess.get(url)
    soup = bs4.BeautifulSoup(resp.text,'lxml')
    target=soup.find('code',{'id':codeID})
    return json.loads(target.contents[0]) if target else {'description':''}

# %%
#set credentials
login={'session_key'       : 'username'
       ,'session_password' : 'password'}

# %%
#start linkedin Session
URL='https://www.linkedin.com/uas/login-submit'
sess=requests.session()
sess.post(URL,data=login)
# Out:
# <Response [200]>

# %%
#search jobs and capture response
searches={'Data Scientist':'https://www.linkedin.com/jobs/search/?keywords=%22Data%20Scientist%22&location=Houston%2C%20Texas'
         ,'Engineer':'https://www.linkedin.com/jobs/search/?keywords=Engineer&location=Houston%2C%20Texas&locationId=PLACES.us.10-4-0-101-12'
         }
pages=get_dict_from_url(searches[SEARCH_TERM],'decoratedJobPostingsModule')

# %%
try:
    data=pd.read_pickle(TODAY_PICKLE_PATH)
except:
    totalPages=len(pages['paging']['pages'])
    currPage=1
    data=pd.DataFrame()
    for page in pages['paging']['pages']:
        print("requesting %d out of %d " % (currPage, totalPages))
        pageURL=BASE_URL+page['pageUrl']
        time.sleep(0.1)
        posts=get_dict_from_url(pageURL,'decoratedJobPostingsModule')
        for post in posts['elements']:
            info=post['decoratedJobPosting']
            info=pd.io.json.json_normalize(info)        
            info['inApply']=post['isInApply']
            info['postURL']=post['viewJobCanonicalUrl']
            data=pd.concat([data,info],axis=0)
        currPage+=1
    data.to_pickle(TODAY_PICKLE_PATH)
# Out:
# requesting 1 out of 10
# requesting 2 out of 10
# requesting 3 out of 10
# requesting 4 out of 10
# requesting 5 out of 10
# requesting 6 out of 10
# requesting 7 out of 10
# requesting 8 out of 10
# requesting 9 out of 10
# requesting 10 out of 10

# %%
#set index and filter to useful columns
data.set_index('jobPosting.id',inplace=True)
data=data[['inApply'
           ,'postURL'
           ,'companyName'
           ,'jobPosting.listDate'
           ,'jobPosting.title']]

# %%
data
# Out:
#               inApply                                       postURL  \
# jobPosting.id
# 381275509        True  https://www.linkedin.com/jobs/view/381275509
# 390358370       False  https://www.linkedin.com/jobs/view/390358370
# 394700972       False  https://www.linkedin.com/jobs/view/394700972
# 365982792        True  https://www.linkedin.com/jobs/view/365982792
# 394184273        True  https://www.linkedin.com/jobs/view/394184273
# 392549944        True  https://www.linkedin.com/jobs/view/392549944
# 390220780       False  https://www.linkedin.com/jobs/view/390220780
# 381248198        True  https://www.linkedin.com/jobs/view/381248198
# 394886720       False  https://www.linkedin.com/jobs/view/394886720
# 396547463       False  https://www.linkedin.com/jobs/view/396547463
# 374779645            1498078001000
# 388532727            1499277983000
# 374487664            1498045219000
# 386476219            1499071417000
# 393727034            1499836579000
# 339771471            1499573921000
# 335739846            1498052790000
# 390273941            1497380405000
# 396654090            1500160727000
#
#                                                 jobPosting.title
# jobPosting.id
# 381275509                                    Structural Engineer
# 390358370          Maintenance Engineer Department (Houston- TX)
# 394700972                                       Project Engineer
# 365982792                                        DevOps Engineer
# 394184273                                 Field Service Engineer
# 392549944                             Technical Support Engineer
# 390220780      NPI TECHNICIAN (New Product Introduction Engin...
# 381248198                              Broadcast System Engineer
# 394886720      12B Combat Engineer - Construction and Enginee...
# 396547463                  Sr. Drilling Engineer (Permian Basin)
# 396597241                                    Blockchain Engineer
# 377211115                   Fixed Equipment Reliability Engineer
# 390768825      Process Engineer | Wastewater Engineering (Wor...
# 393313960                                 Automation Engineer II
# 390199551             Asset Integrity Analyst (Project Engineer)
# 352379893                   Sr. Engineer I - Quality Engineering
# 398286295                               Senior Software Engineer
# 389911005                                Reservoir Engineer II
# 395709204      Infrastructure Engineer Manager - Global Netwo...
# 333007920                                  Construction Engineer
# 396494595      Industrial Sales Engineer - Heat Exchanger and...
# 358180357                                           OEM Engineer
# 365987577                    Technical Support Engineer (OnBase)
# 392869657                                     Sr. Engineer Staff
# 388353220                                       Quality Engineer
# 398216169                   Instrumentation Reliability Engineer
# 372810988                      Drilling Engineer - Onshore Texas
# 391984686      Reservoir Engineer - Business Development - 18...
# 355664230                                         Sales Engineer
# 397929360                                        Engineer Intern
# ...                                                          ...
# 392496640                              Software Quality Engineer
# 392500262                                         SCADA Engineer
# 376474636                                Field Service Engineer
# 394072912                           Senior Network Engineer-CCNP
# 390192844             Instrumentation & Controls Engineer (8694)
# 376474636                                Field Service Engineer
# 394072912                           Senior Network Engineer-CCNP
# 390192844             Instrumentation & Controls Engineer (8694)
# 395086992                              Robotic Software Engineer
# 392484491                                  HPC Engineer - travel
# 397410259                          Sr. Network Security Engineer
# 372668798                                            Sr Engineer
# 349321314                               Applications Engineer II
# 334635944                Junior Windows Server InfraOps Engineer
# 384374131                                            QA Engineer
# 390364051                       Maintenance Engineer (Overnight)
# 371785149                                   Sr. Systems Engineer
# 372932589       Software Engineer - Mobile Application Developer
# 392922712                                    Production Engineer
# 391136727                       Cloud Security Software Engineer
# 383932683                                 Outside Sales Engineer
# 374779645                          Software Engineer - Numerical
# 388532727                                       Network Engineer
# 374487664               Senior Stimulation / Completion Engineer
# 386476219                                Cloud Software Engineer
# 393727034                              Civil Structural Engineer
# 339771471      12B Combat Engineer - Construction and Enginee...
# 335739846                                      Drainage Engineer
# 390273941                                       Project Engineer
# 396654090                                      Software Engineer
#
# [250 rows x 5 columns]

# %%
#fetch job descriptions
for (index,value) in data['postURL'].iteritems():
    currPicklePath=PICKLE_PATH+SEARCH_TERM+'/'+str(index)+'.pickle'
    try:
        desc=pickle.load(open(currPicklePath,'rb'))
    except:
        time.sleep(0.5)
        desc=get_dict_from_url(value,'jobDescriptionModule')
        pickle.dump(desc,open(currPicklePath,'wb'))
    data.loc[index,'description'] = desc['description']
# Out:
# /usr/lib/python3/dist-packages/pandas/core/indexing.py:477: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
